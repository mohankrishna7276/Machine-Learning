# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('/content/sample_data/california_housing_test.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification
x,y=make_classification(n_samples=1000,n_features=20,random_state=42)
lr=LogisticRegression()
rfe=RFE(lr,n_features_to_select=5)
x_selected=rfe.fit_transform(x,y)
print("Selected Features:",rfe.support_)
print("Feature Ranking:",rfe.ranking_)
# Out:
# Selected Features: [False  True False False False  True False False False False False  True
#  False False  True False False False  True False]
# Feature Ranking: [ 8  1  2  4 12  1  7 13 15 16  3  1 14  6  1  9 10  5  1 11]

# %%
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
x,y=make_classification(n_samples=1000,n_features=10,n_informative=5,n_redundant=5,random_state=1)
rfe=RFE(estimator=DecisionTreeClassifier(),n_features_to_select=5)
model=DecisionTreeClassifier()
pipeline=Pipeline(steps=[('s1',rfe),('m1',model)])
cv=RepeatedStratifiedKFold(n_splits=10,n_repeats=3,random_state=1)
n_scores=cross_val_score(pipeline,x,y,scoring='accuracy',cv=cv,n_jobs=-1,error_score='raise')
print('Accuracy: %.3f (%.3f)'%(mean(n_scores),std(n_scores)))
data=[[2.56999479,-0.13019997,3.16075093,-4.35936352,1.61271951,-1.39352057,-2.48924933,1.93094078,3.26130366,2.05692145]]
yhat=pipeline.predict(data)
print('Predicted Class: %d'%(yhat))
# Out:
# Accuracy: 0.887 (0.030)
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py in _raise_or_warn_if_not_fitted(estimator)
#      53     try:
# ---> 54         yield
#      55     except NotFittedError as exc:
#
# /usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py in predict(self, X, **params)
#     786                 for _, name, transform in self._iter(with_final=False):
# --> 787                     Xt = transform.transform(Xt)
#     788                 return self.steps[-1][1].predict(Xt, **params)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_base.py in transform(self, X)
#     115         )
# --> 116         return self._transform(X)
#     117
#
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_base.py in _transform(self, X)
#     119         """Reduce X to the selected features."""
# --> 120         mask = self.get_support()
#     121         if not mask.any():
#
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_base.py in get_support(self, indices)
#      71         """
# ---> 72         mask = self._get_support_mask()
#      73         return mask if not indices else np.where(mask)[0]
#
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_rfe.py in _get_support_mask(self)
#     449     def _get_support_mask(self):
# --> 450         check_is_fitted(self)
#     451         return self.support_
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1756     if not _is_fitted(estimator, attributes, all_or_any):
# -> 1757         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1758
#
# NotFittedError: This RFE instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.
#
# The above exception was the direct cause of the following exception:
#
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-12-8d6dc15a1525> in <cell line: 0>()
#      15 print('Accuracy: %.3f (%.3f)'%(mean(n_scores),std(n_scores)))
#      16 data=[[2.56999479,-0.13019997,3.16075093,-4.35936352,1.61271951,-1.39352057,-2.48924933,1.93094078,3.26130366,2.05692145]]
# ---> 17 yhat=pipeline.predict(data)
#      18 print('Predicted Class: %d'%(yhat))
#
# /usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py in predict(self, X, **params)
#     780         """
#     781         # TODO(1.8): Remove the context manager and use check_is_fitted(self)
# --> 782         with _raise_or_warn_if_not_fitted(self):
#     783             Xt = X
#     784
#
# /usr/lib/python3.11/contextlib.py in __exit__(self, typ, value, traceback)
#     156                 value = typ()
#     157             try:
# --> 158                 self.gen.throw(typ, value, traceback)
#     159             except StopIteration as exc:
#     160                 # Suppress StopIteration *unless* it's the same exception that
#
# /usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py in _raise_or_warn_if_not_fitted(estimator)
#      54         yield
#      55     except NotFittedError as exc:
# ---> 56         raise NotFittedError("Pipeline is not fitted yet.") from exc
#      57
#      58     # we only get here if the above didn't raise
#
# NotFittedError: Pipeline is not fitted yet.
