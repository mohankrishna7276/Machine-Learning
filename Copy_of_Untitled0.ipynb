# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("/iris.csv")
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
x=df[df.columns[0:4]]
print(x)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y=df['variety']
print(y)
# Out:
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
#          ...
# 145    Virginica
# 146    Virginica
# 147    Virginica
# 148    Virginica
# 149    Virginica
# Name: variety, Length: 150, dtype: object

# %%
sns.pairplot(df)

# %%
sns.countplot(data=x,x=y)
# Out:
# <Axes: xlabel='variety', ylabel='count'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()
log.fit(x_train,y_train)
y_predict=log.predict(x_test)
from sklearn.metrics import accuracy_score
print('Accuracy(logistic regression):',accuracy_score(y_predict,y_test))
from sklearn.metrics import confusion_matrix
log_matrix=confusion_matrix(y_test,y_predict)
print('Confusion matrix(logistic regression):\n',log_matrix)
print("heat map(logistic regression)")
sns.heatmap(log_matrix,annot=True,xticklabels=y.unique(),yticklabels=y.unique())
# Out:
# Accuracy(logistic regression): 1.0
# Confusion matrix(logistic regression):
#  [[10  0  0]
#  [ 0 10  0]
#  [ 0  0 10]]
# heat map(logistic regression)
# <Axes: >

# %% [markdown]
# KNN

# %%
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()
log.fit(x_train,y_train)
y_predict=log.predict(x_test)
from sklearn.metrics import accuracy_score
print('Accuracy(logistic regression):',accuracy_score(y_predict,y_test))
from sklearn.metrics import confusion_matrix
log_matrix=confusion_matrix(y_test,y_predict)
print('Confusion matrix(logistic regression):\n',log_matrix)
print("heat map(logistic regression)")
sns.heatmap(log_matrix,annot=True,xticklabels=y.unique(),yticklabels=y.unique())
# Out:
# Accuracy(logistic regression): 1.0
# Confusion matrix(logistic regression):
#  [[10  0  0]
#  [ 0 10  0]
#  [ 0  0 10]]
# heat map(logistic regression)
# <Axes: >

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(x_train, y_train)
rf_y_predict= rf.predict(x_test)
rf_accuracy = accuracy_score(y_test,rf_y_predict)
print("Accuracy(random forest):",rf_accuracy)
from sklearn.metrics import confusion_matrix
rf_matrix=confusion_matrix(y_test,rf_y_predict)
print('Confusion matrix(rf):\n',rf_matrix)
print("heat map(random forest))")
sns.heatmap(rf_matrix,annot=True,xticklabels=y.unique(),yticklabels=y.unique())
# Out:
# Accuracy(random forest): 1.0
# Confusion matrix(rf):
#  [[10  0  0]
#  [ 0 10  0]
#  [ 0  0 10]]
# heat map(random forest))
# <Axes: >

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
dt_y_predict = dt.predict(x_test)
dt_accuracy = accuracy_score(y_test, dt_y_predict)
print("Accuracy(decision tree):",dt_accuracy)
from sklearn.metrics import confusion_matrix
dt_matrix=confusion_matrix(y_test,dt_y_predict)
print('Confusion matrix(dt):\n',dt_matrix)
print("heat map(decision tree))")
sns.heatmap(dt_matrix,annot=True,xticklabels=y.unique(),yticklabels=y.unique())
# Out:
# Accuracy(decision tree): 0.9666666666666667
# Confusion matrix(dt):
#  [[10  0  0]
#  [ 0 10  0]
#  [ 0  1  9]]
# heat map(decision tree))
# <Axes: >

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVC
svm = SVC()
svm.fit(x_train, y_train)
svm_y_predict = dt.predict(x_test)
svm_accuracy = accuracy_score(y_test,svm_y_predict)
print("Accuracy(svm):",svm_accuracy)
from sklearn.metrics import confusion_matrix
svm_matrix=confusion_matrix(y_test,svm_y_predict)
print('Confusion matrix(svm):\n',svm_matrix)
print("heat map(svm))")
sns.heatmap(svm_matrix,annot=True,xticklabels=y.unique(),yticklabels=y.unique())
# Out:
# Accuracy(svm): 0.9666666666666667
# Confusion matrix(svm):
#  [[10  0  0]
#  [ 0 10  0]
#  [ 0  1  9]]
# heat map(svm))
# <Axes: >
